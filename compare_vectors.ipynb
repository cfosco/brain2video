# %% [markdown]
# # Notebook to compare reconstructed vectors and targets

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Load reconstructed vectors

recons_vecs_path = "./estimated_vectors/WB_c_zeroscope/"

recons_vecs = np.load(recons_vecs_path + "preds_test.npy")
print(recons_vecs.shape)
# Out:
# (102, 78848)

# %%
# Load ground truth vectors

gt_vecs_path = "./data/target_vectors/c_zeroscope/"
gt_vecs = []
train_range = range(1, 1001)
test_range = range(1001, 1103)
for v in test_range:
    gt_vecs.append(np.load(gt_vecs_path + f'{v:04d}.npy'))

gt_vecs = np.array(gt_vecs)
print(gt_vecs.shape)
# Out:
# (102, 78848)

# %%
# Compare vectors  

def compare_vectors(recons_vecs, gt_vecs, n):
    plt.figure(figsize=(20,10))
    plt.plot(recons_vecs[n], label="reconstructed")
    plt.plot(gt_vecs[n], label="ground truth", alpha=0.5)
    plt.legend()
    plt.show()

compare_vectors(recons_vecs, gt_vecs, 8)
